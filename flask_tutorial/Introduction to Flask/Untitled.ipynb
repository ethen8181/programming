# %%
import pandas as pd

# %%
data = pd.read_csv('static/data/' + 'bankcase' + '.csv')

# %%
data
# Out:
#          ID CUST_OPN_DT  NBROPN   AGE           CITY STATE  PSTL_CD_5  \
# 0     22794  07/15/1994       3  35.0        SEATTLE    WA    98105.0
# 1     23835  01/07/1996       2  54.0     BELLINGHAM    WA    98225.0
# 2      2597  04/01/1974       7  61.0      ROCHESTER    MN    55901.0
# 3     44853  07/26/1982       1  52.0    SAN ANSELMO    CA    94960.0
# 4      4388  10/01/1977       1  55.0            ELY    MN    55731.0
# 5     23239  01/01/1981       2  86.0       PORTLAND    OR    97215.0
# 6     29930  02/15/1995       1  56.0     CINCINNATI    OH    45251.0
# 7     39774  11/01/1999       2  40.0   POPLAR BLUFF    MO    63901.0
# 8      5385  11/20/1997       1  50.0         AURORA    CO    80014.0
# 9      6297  04/07/2000       2  32.0      GRANDVIEW    WA    98930.0
# 10    37616  10/03/1998       1  25.0       OAK PARK    IL    60304.0
# 11    46882  01/01/1962       1  87.0       BELLEVUE    WA    98009.0
# ...
