# %%
import urllib.request
import collections
import math
import os
import random
import zipfile
import datetime as dt

import numpy as np
import tensorflow as tf

# %%
def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    
    return filename


filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words."""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    
    return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)

    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)

    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary


data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3082, 12, 6, 195, 2, 3136, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
data[:10]
# Out:
# [5239, 3082, 12, 6, 195, 2, 3136, 46, 59, 156]

# %%
data_index = 0
batch = np.zeros(batch_size, dtype = np.uint32)
labels = np.zeros((batch_size, 1), dtype = np.uint32)
span = 2 * skip_window + 1  # [skip_window target skip_window]
print(span)
buffer = collections.deque(maxlen = span)
for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
# Out:
# 3

# %%
buffer
# Out:
# deque([7774, 2939, 496])

# %%
data_index
# Out:
# 3

# %%
data_index = 0


# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]

        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels


batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
          '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3082 originated -> 12 as
# 3082 originated -> 5239 anarchism
# 12 as -> 3082 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
        tf.nn.nce_loss(weights=nce_weights,
                       biases=nce_biases,
                       labels=train_labels,
                       inputs=embed,
                       num_sampled=num_sampled,
                       num_classes=vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Add variable initializer.
    init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001
with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print('Initialized')

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step ', step, ': ', average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = '%s %s,' % (log_str, close_word)
                print(log_str)

    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  289.921142578
# Nearest to i: barberini, malacca, rei, hasidim, celtics, gloom, infanta, media,
# Nearest to after: birding, soles, undercover, unbeaten, tsuka, frites, invalidating, boc,
# Nearest to zero: certainly, xj, rhetorician, warhol, overwhelms, introns, vale, urgell,
# Nearest to american: escalator, nanometers, detriment, lackey, lobo, srinagar, headstone, attributed,
# Nearest to nine: scoop, tout, protester, containing, kush, litas, polyn, motets,
# Nearest to and: originator, deeply, dwan, as, josh, brokers, ensue, rig,
# Nearest to been: beirut, practically, lejeune, chime, symbolically, ebony, boroughs, pelham,
# Nearest to would: sx, plenipotentiary, sewing, feud, checking, broadly, piero, exon,
# Nearest to often: muller, hosting, polyidus, schoenberg, peripatetic, sculpture, mammalia, epithets,
# Nearest to as: and, guy, timescale, deteriorated, glitter, credits, lau, galatea,
# Nearest to at: ero, etiquette, dogmatically, buckle, assisting, glycosylation, klux, customarily,
# Nearest to during: menu, ax, sunken, committing, husserl, augusta, thoroughfares, focussing,
# Nearest to over: diverting, afternoon, xvii, xxv, fibers, feininger, humanitarian, elway,
# Nearest to if: outsold, layoffs, proofing, scarecrow, pes, elmira, actually, biting,
# Nearest to more: ipkf, harbored, unopened, awake, enjoined, bankrupted, borgir, hyphens,
# Nearest to new: peak, initiated, odore, tendencies, cognate, viewed, tidewater, episcopacy,
# Average loss at step  2000 :  113.846555792
# Average loss at step  4000 :  52.4000242765
# Average loss at step  6000 :  33.4861202781
# Average loss at step  8000 :  23.6064036045
# Average loss at step  10000 :  17.5187575071
# Nearest to i: media, capitalists, third, modified, crazy, partner, vs, therapeutic,
# Nearest to after: and, sale, in, gb, molinari, morocco, sx, raging,
# Nearest to zero: nine, eight, vs, phi, austin, aberdeen, archie, six,
# Nearest to american: attributed, finalist, greatest, lethbridge, frisian, effective, your, lillian,
# Nearest to nine: zero, austin, eight, phi, six, archie, bckgr, aberdeen,
# Nearest to and: in, of, or, archie, nine, for, the, agave,
# Nearest to been: boroughs, practically, necessarily, canals, adobe, were, nonempty, affordable,
# Nearest to would: sx, needs, gb, checking, agincourt, weight, hampered, lead,
# Nearest to often: hosting, she, approximately, vocals, served, steadily, distinctly, vs,
# Nearest to as: and, in, bckgr, by, province, afghanistan, archie, phi,
# Nearest to at: in, of, neolithic, major, abstract, alex, feeling, etiquette,
# Nearest to during: guns, augusta, pursuing, corals, fears, and, committing, affinities,
# Nearest to over: counter, gland, afternoon, fifth, remove, encyclopedias, literally, iceland,
# Nearest to if: actually, practices, audi, biting, causes, have, hurricanes, proofing,
# Nearest to more: price, kramnik, campbell, harbored, spoof, notes, aberdeen, exploration,
# Nearest to new: peak, boats, tendencies, viewed, character, autistics, emperor, contribution,
# Average loss at step  12000 :  14.0721012089
# Average loss at step  14000 :  11.5993874176
# Average loss at step  16000 :  9.95714084291
# Average loss at step  18000 :  8.4076678139
# Average loss at step  20000 :  8.05091270125
# Nearest to i: media, capitalists, crazy, partner, ashoka, two, simplicity, operatorname,
# Nearest to after: and, at, of, in, circ, sale, polish, raging,
# Nearest to zero: nine, eight, five, six, seven, four, three, two,
# Nearest to american: and, finalist, d, attributed, frisian, depleted, lethbridge, your,
# Nearest to nine: eight, six, seven, zero, five, dasyprocta, operatorname, three,
# Nearest to and: of, or, in, circ, operatorname, agouti, dasyprocta, UNK,
# Nearest to been: boroughs, were, practically, was, necessarily, by, canals, turkic,
# Nearest to would: sx, needs, pronounce, lombards, valued, commentaries, gb, to,
# Nearest to often: hosting, she, muller, there, tribune, now, distinctly, agouti,
# Nearest to as: and, is, by, was, in, dasyprocta, for, seti,
# Nearest to at: in, acapulco, of, and, with, alex, operatorname, after,
# Nearest to during: and, menu, in, of, augusta, fears, guns, affinities,
# Nearest to over: counter, circ, dasyprocta, remove, vaccines, afternoon, or, encyclopedias,
# Nearest to if: actually, operatorname, practices, shari, audi, three, are, have,
# Nearest to more: kramnik, clubs, price, futuristic, including, spoof, campbell, discontinuous,
# Nearest to new: peak, onyx, arius, tendencies, boats, autistics, agouti, dasyprocta,
# Average loss at step  22000 :  7.09344186461
# Average loss at step  24000 :  6.8984678123
# Average loss at step  26000 :  6.80351591229
# Average loss at step  28000 :  6.43235814488
# Average loss at step  30000 :  5.9256912868
# Nearest to i: bos, media, crazy, two, capitalists, partner, ashoka, simplicity,
# Nearest to after: in, at, and, around, sale, circ, with, polish,
# Nearest to zero: six, five, eight, seven, nine, four, three, two,
# Nearest to american: and, d, english, one, finalist, chose, depleted, attributed,
# Nearest to nine: eight, six, seven, five, four, zero, three, operatorname,
# Nearest to and: or, in, but, circ, abet, almighty, of, s,
# Nearest to been: were, was, practically, by, boroughs, necessarily, canals, turkic,
# Nearest to would: could, to, can, may, sx, tracked, lombards, otimes,
# Nearest to often: hosting, she, schoenberg, there, now, muller, still, tribune,
# Nearest to as: and, by, in, dasyprocta, is, with, circ, for,
# Nearest to at: in, with, acapulco, after, of, almighty, on, six,
# Nearest to during: in, and, tnf, of, menu, fears, augusta, affinities,
# Nearest to over: circ, counter, dasyprocta, remove, three, vaccines, manage, stormed,
# Nearest to if: actually, three, but, shari, are, with, outsold, practices,
# Nearest to more: kramnik, futuristic, clubs, including, discontinuous, agouti, spoof, harbored,
# Nearest to new: peak, otimes, tendencies, onyx, arius, character, agouti, episcopacy,
# Average loss at step  32000 :  5.9772632066
# Average loss at step  34000 :  5.73307368064
# Average loss at step  36000 :  5.8119421649
# Average loss at step  38000 :  5.51064093399
# Average loss at step  40000 :  5.27825696546
# Nearest to i: capitalists, crazy, bos, simplicity, they, partner, media, UNK,
# Nearest to after: at, birding, around, sale, circ, in, before, with,
# Nearest to zero: dasyprocta, eight, agouti, six, seven, operatorname, nine, five,
# Nearest to american: and, english, chose, zero, depleted, finalist, aveiro, d,
# Nearest to nine: eight, six, seven, zero, five, four, three, operatorname,
# Nearest to and: or, zero, in, but, almighty, recitative, peptide, circ,
# Nearest to been: was, were, be, practically, necessarily, by, boroughs, turkic,
# Nearest to would: can, may, could, will, to, tracked, sx, zero,
# Nearest to often: hosting, now, there, still, she, schoenberg, muller, sometimes,
# Nearest to as: dasyprocta, and, by, circ, seti, is, operatorname, agouti,
# Nearest to at: in, on, almighty, acapulco, after, six, with, from,
# Nearest to during: in, tnf, and, of, fears, menu, augusta, zero,
# Nearest to over: four, three, circ, dasyprocta, eight, vaccines, afternoon, five,
# Nearest to if: actually, but, with, three, operatorname, acceleration, shari, zero,
# Nearest to more: less, discontinuous, kramnik, including, very, clubs, futuristic, most,
# Nearest to new: peak, agouti, tendencies, character, catalog, contribution, otimes, dasyprocta,
# Average loss at step  42000 :  5.38430806327
# Average loss at step  44000 :  5.26026919734
# Average loss at step  46000 :  5.23992094553
# Average loss at step  48000 :  5.21894156885
# Average loss at step  50000 :  4.9888522979
# Nearest to i: they, capitalists, bos, crazy, simplicity, partner, operatorname, media,
# Nearest to after: at, before, birding, kapoor, around, during, six, sale,
# Nearest to zero: eight, six, seven, five, nine, four, three, dasyprocta,
# Nearest to american: english, and, chose, aveiro, finalist, one, d, lethbridge,
# Nearest to nine: eight, six, seven, zero, three, four, five, dasyprocta,
# Nearest to and: or, but, eight, four, circ, six, dasyprocta, almighty,
# Nearest to been: were, was, be, practically, by, necessarily, had, turkic,
# Nearest to would: can, will, may, could, to, should, did, tracked,
# Nearest to often: hosting, now, still, generally, there, also, sometimes, she,
# Nearest to as: by, circ, dasyprocta, for, operatorname, agouti, seti, five,
# Nearest to at: in, three, almighty, on, six, after, with, from,
# Nearest to during: in, tnf, at, after, when, before, of, fears,
# Nearest to over: three, four, vaccines, circ, dasyprocta, afternoon, stormed, manage,
# Nearest to if: when, but, three, acceleration, actually, outsold, like, operatorname,
# Nearest to more: less, most, very, discontinuous, harbored, including, agouti, recitative,
# Nearest to new: peak, bouldering, contribution, agouti, tendencies, catalog, character, dasyprocta,
# Average loss at step  52000 :  5.03058161771
# Average loss at step  54000 :  5.21040513647
# Average loss at step  56000 :  5.03182821763
# Average loss at step  58000 :  5.05792328262
# Average loss at step  60000 :  4.95265821528
# Nearest to i: they, crazy, capitalists, you, t, bos, simplicity, celtics,
# Nearest to after: before, during, birding, kapoor, at, six, around, circ,
# Nearest to zero: seven, eight, six, five, nine, four, three, dasyprocta,
# Nearest to american: and, english, chose, finalist, sulfate, french, allowance, aveiro,
# Nearest to nine: eight, seven, six, four, five, zero, ursus, operatorname,
# Nearest to and: or, but, kapoor, ursus, almighty, recitative, circ, dasyprocta,
# Nearest to been: be, was, were, had, practically, turkic, by, necessarily,
# Nearest to would: can, will, may, could, should, to, must, did,
# Nearest to often: now, hosting, still, sometimes, generally, also, there, she,
# Nearest to as: dasyprocta, circ, by, wct, michelob, in, and, seti,
# Nearest to at: in, on, six, almighty, during, after, five, pulau,
# Nearest to during: in, after, at, when, tnf, before, fears, of,
# Nearest to over: three, four, six, dasyprocta, circ, vaccines, eight, five,
# Nearest to if: when, but, actually, acceleration, three, operatorname, where, agouti,
# Nearest to more: less, most, very, agouti, recitative, wct, discontinuous, rather,
# Nearest to new: peak, bouldering, agouti, ursus, contribution, precession, dasyprocta, crab,
# Average loss at step  62000 :  5.01100915205
# Average loss at step  64000 :  4.82732207501
# Average loss at step  66000 :  4.60688724792
# Average loss at step  68000 :  4.99091182101
# Average loss at step  70000 :  4.87265067983
# Nearest to i: they, UNK, you, cebus, capitalists, crazy, t, simplicity,
# Nearest to after: before, during, birding, at, kapoor, when, around, in,
# Nearest to zero: eight, five, six, seven, nine, four, three, ursus,
# Nearest to american: frf, english, and, chose, finalist, french, lethbridge, poor,
# Nearest to nine: eight, seven, six, five, four, zero, three, ursus,
# Nearest to and: or, but, microcebus, ursus, circ, almighty, kapoor, callithrix,
# Nearest to been: be, was, were, had, practically, become, turkic, resisted,
# Nearest to would: can, will, may, could, should, must, did, might,
# Nearest to often: now, still, generally, sometimes, also, hosting, there, she,
# Nearest to as: dasyprocta, circ, cobbler, wct, michelob, microcebus, by, and,
# Nearest to at: in, during, three, after, almighty, on, clo, six,
# Nearest to during: in, after, when, at, tnf, before, fears, almighty,
# Nearest to over: three, four, vaccines, into, microcebus, circ, exodus, dasyprocta,
# Nearest to if: when, but, acceleration, where, then, three, can, actually,
# Nearest to more: less, most, very, agouti, rather, recitative, discontinuous, wct,
# Nearest to new: peak, precession, dist, bouldering, agouti, ursus, tendencies, trapezohedron,
# Average loss at step  72000 :  4.74476474285
# Average loss at step  74000 :  4.82634223139
# Average loss at step  76000 :  4.71922012198
# Average loss at step  78000 :  4.79011055279
# Average loss at step  80000 :  4.79590303701
# Nearest to i: UNK, barberini, they, busan, t, you, cebus, g,
# Nearest to after: before, during, birding, when, at, around, in, kapoor,
# Nearest to zero: five, eight, six, four, seven, nine, three, ursus,
# Nearest to american: english, frf, french, chose, and, british, lethbridge, finalist,
# Nearest to nine: eight, seven, six, five, four, zero, ursus, dasyprocta,
# Nearest to and: or, but, microcebus, ursus, kapoor, recitative, circ, almighty,
# Nearest to been: be, were, was, become, had, varphi, practically, resisted,
# Nearest to would: can, will, may, could, must, should, might, to,
# Nearest to often: now, sometimes, still, generally, also, hosting, there, commonly,
# Nearest to as: circ, dasyprocta, michelob, wct, cobbler, microcebus, agouti, ursus,
# Nearest to at: in, on, around, during, after, almighty, clo, six,
# Nearest to during: in, after, when, before, tnf, at, of, fears,
# Nearest to over: four, five, microcebus, three, vaccines, into, dasyprocta, circ,
# Nearest to if: when, then, where, time, but, acceleration, actually, germanicus,
# Nearest to more: less, most, very, rather, agouti, recitative, discontinuous, wct,
# Nearest to new: peak, precession, agouti, dist, tendencies, ursus, bouldering, dasyprocta,
# Average loss at step  82000 :  4.76720208752
# Average loss at step  84000 :  4.75115857828
# Average loss at step  86000 :  4.76454057848
# Average loss at step  88000 :  4.75182633078
# Average loss at step  90000 :  4.73045843697
# Nearest to i: they, you, barberini, UNK, t, busan, ii, cebus,
# Nearest to after: before, during, when, birding, at, six, around, kapoor,
# Nearest to zero: five, eight, seven, six, four, nine, three, ursus,
# Nearest to american: english, frf, french, british, chose, national, poor, lethbridge,
# Nearest to nine: eight, seven, six, five, four, zero, three, ursus,
# Nearest to and: or, but, while, ursus, kapoor, microcebus, recitative, circ,
# Nearest to been: be, was, were, become, had, resisted, varphi, azali,
# Nearest to would: will, can, may, could, should, must, might, to,
# Nearest to often: now, sometimes, generally, still, also, there, hosting, usually,
# Nearest to as: cobbler, circ, dasyprocta, michelob, microcebus, by, wct, seti,
# Nearest to at: in, during, around, on, six, after, within, clo,
# Nearest to during: in, after, when, at, before, tnf, tenet, and,
# Nearest to over: three, into, exodus, oxus, vaccines, microcebus, circ, manage,
# Nearest to if: when, where, then, time, acceleration, agouti, but, germanicus,
# Nearest to more: less, most, very, rather, agouti, wct, calypso, discontinuous,
# Nearest to new: precession, dist, ursus, agouti, peak, dasyprocta, bouldering, peacocks,
# Average loss at step  92000 :  4.67887489772
# Average loss at step  94000 :  4.72975400293
# Average loss at step  96000 :  4.70057640386
# Average loss at step  98000 :  4.58335727787
# Average loss at step  100000 :  4.69893939567
# Nearest to i: you, they, barberini, t, ii, busan, cebus, thaler,
# Nearest to after: before, during, when, birding, at, around, in, kapoor,
# Nearest to zero: eight, five, nine, four, seven, six, three, ursus,
# Nearest to american: english, british, french, frf, and, german, allowance, finalist,
# Nearest to nine: eight, seven, six, five, zero, four, three, ursus,
# Nearest to and: or, but, kapoor, microcebus, ursus, including, while, recitative,
# Nearest to been: be, was, become, were, had, resisted, azali, varphi,
# Nearest to would: will, can, could, may, should, must, might, did,
# Nearest to often: sometimes, now, generally, still, also, usually, hosting, there,
# Nearest to as: circ, dasyprocta, cobbler, michelob, wct, microcebus, agouti, seti,
# Nearest to at: in, during, around, after, on, within, clo, almighty,
# Nearest to during: in, after, when, at, before, tnf, almighty, tenet,
# Nearest to over: into, three, microcebus, vaccines, exodus, oxus, place, dasyprocta,
# Nearest to if: when, where, then, time, is, agouti, while, acceleration,
# Nearest to more: less, most, very, rather, agouti, wct, recitative, aberdeen,
# Nearest to new: precession, bouldering, dist, peak, tendencies, lnot, stenella, ursus,
